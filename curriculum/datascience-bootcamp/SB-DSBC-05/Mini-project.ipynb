# %% [markdown]
# # Mini-Project - Build Your Own Model
#
# © 2016 STREAMBRIGHT DATA LLC, ALL RIGHTS RESERVED
#
# The goal with this exercise to practice the skills and codes you have learned during today sessions.
#
# During the next 1-2 hours you should build your own kNN classification models and fine-tune it to get the best scores for your classification.
#
# **Here are the tasks you should do:**
#
# * load the dataset that you will find in this folder called 'heart-disease.csv'
# * examine the different variables
# * clean the dataset
#  * handle missing data
#  * handle outliers if you find any
# * explore different visualizations to get familiar with the features
# * build a classification model (do not forget to split the data into training and test sets)
# * assess its classification power (use cross-validation)
# * fine-tune your model until you get the best performing one
#  * tweek parameters (maybe use GridSearchCV)
#  * play around with using only a subset or the features
#  * transform features if necessary (scaling, log, sqrt), or just try out whether it increases the scoring power
#
# **Tips:**
# * use the notebooks we have presented during the day to find the codes
# * use the packages' documentation if you get stuck
#  * Numpy: http://docs.scipy.org/doc/
#  * Pandas: http://pandas.pydata.org/pandas-docs/stable/
#  * Sci-kit Learn: http://scikit-learn.org/stable/modules/neighbors.html
# * use google if you run into an error message or problem (http://stackoverflow.com/)
# * ask any of us if we are nearby! We are happy to help.
#
# **About the dataset:**
#
# We use the "Heart Disease Data Set" from the UCI Machine Learning Repository (http://archive.ics.uci.edu/ml/datasets/Heart+Disease).
#
# This database contains 76 attributes, but all published experiments refer to using a subset of 14 of them. The "num" field refers to the presence of heart disease in the patient. Originally it was an integer valued from 0 (no presence) to 4. In this dataset it has been recoded to 0 and 1 - to simply attempt to distinguish presence (values 1,2,3,4 before now 1) from absence (value 0).
#
# Here are the 14 features we have in the dataset:
#
# feature name | description
# -- | --
# age | age in years
# sex | sex (1 = male; 0 = female)
# cp | chest pain type (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4: asymptomatic)
# trestbps | resting blood pressure (in mm Hg on admission to the hospital)
# chol | serum cholestoral in mg/dl
# fbs | (fasting blood sugar > 120 mg/dl)  (1 = true; 0 = false)
# restecg | resting electrocardiographic results (Value 0: normal, Value 1: having ST-T wave abnormality (T wave inversions and/or ST elevation or depression of > 0.05 mV), Value 2: showing probable or definite left ventricular hypertrophy by Estes' criteria)
# thalach | maximum heart rate achieved
# exang | exercise induced angina (1 = yes; 0 = no)
# oldpeak | ST depression induced by exercise relative to rest
# slope | the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
# ca | number of major vessels (0-3) colored by flourosopy
# thal | 3 = normal; 6 = fixed defect; 7 = reversable defect
# num | Target label: 0 absence, 1 presence
#
# **Evaluation:**
#
# Optionally you can submit your final model for an evaluation. For the evaluation we will use separate dataset with new observations to avoid that you overfit the data to the evaluation set.
#
# Your submisson should be a notebook containing the code from opening the dataset until the fitting of the model. Please make sure the object containing your model called 'knn'.
#
# Also please create a list with the names of the features you use ( features = your_dataframe.columns ).
